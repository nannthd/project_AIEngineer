# %% [markdown]
# <a href="https://colab.research.google.com/github/nannthd/project_AIEngineer/blob/main/model2_yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLOv8

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.2/78.2 GB disk)

# %%
# !pip install pytube opencv-python-headless
# Out:
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (4.10.0.82)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python-headless) (1.25.2)
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %% [markdown]
# ## Custom Training

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="AWtZRbYK04sFZNNZ1t4X")
project = rf.workspace("projectaiengineer").project("coconut-uyte5")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.32-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.3 MB/s eta 0:00:00
# Collecting certifi==2023.7.22 (from roboflow)
#   Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 10.3 MB/s eta 0:00:00
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 24.7 MB/s eta 0:00:00
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.25.2)
# Collecting opencv-python-headless==4.8.0.74 (from roboflow)
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.4)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.4 MB/s eta 0:00:00
# Collecting python-magic (from roboflow)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.53.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# WARNING: The candidate selected for download or install is a yanked version: 'opencv-python-headless' candidate (version 4.8.0.74 at https://files.pythonhosted.org/packages/76/02/f128517f3ade4bb5f71e2afd8461dba70e3f466ce745fa1fd1fade9ad1b7/opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/opencv-python-headless/) (requires-python:>=3.6))
# Reason for being yanked: deprecated, use 4.8.0.76
# Installing collected packages: python-magic, python-dotenv, opencv-python-headless, idna, cycler, chardet, certifi, requests-toolbelt, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.10.0.82
#     Uninstalling opencv-python-headless-4.10.0.82:
#       Successfully uninstalled opencv-python-headless-4.10.0.82
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.6.2
#     Uninstalling certifi-2024.6.2:
#       Successfully uninstalled certifi-2024.6.2
# Successfully installed certifi-2023.7.22 chardet-4.0.0 cycler-0.10.0 idna-2.10 opencv-python-headless-4.8.0.74 python-dotenv-1.0.1 python-magic-0.4.27 requests-toolbelt-1.0.0 roboflow-1.1.32
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in coconut-1 to yolov8:: 100%|██████████| 10626/10626 [00:01<00:00, 5805.79it/s]
# Extracting Dataset Version Zip to coconut-1 in yolov8:: 100%|██████████| 422/422 [00:00<00:00, 7024.58it/s]

# %%
# %cat {dataset.location}/data.yaml
# Out:
# names:
# - coconut
# nc: 1
# roboflow:
#   license: CC BY 4.0
#   project: coconut-uyte5
#   url: https://universe.roboflow.com/projectaiengineer/coconut-uyte5/dataset/1
#   version: 1
#   workspace: projectaiengineer
# test: test/images
# train: train/images
# val: valid/images

# %%
# !sed -i '$d' {dataset.location}/data.yaml
# !sed -i '$d' {dataset.location}/data.yaml
# !sed -i '$d' {dataset.location}/data.yaml
# !sed -i '$d' {dataset.location}/data.yaml
# !echo -e "test: ../test/images\ntrain: ../train/images\nval: ../valid/images" >> {dataset.location}/data.yaml

# %%
# %cat {dataset.location}/data.yaml
# Out:
# names:
# - coconut
# nc: 1
# roboflow:
#   license: CC BY 4.0
#   project: coconut-uyte5
#   url: https://universe.roboflow.com/projectaiengineer/coconut-uyte5/dataset/1
#   version: 1
# test: ../test/images
# train: ../train/images
# val: ../valid/images

# %% [markdown]
# ## Custom Training

# %%
# %rm -rf /content/runs

# %%
# %cd {HOME}

# !yolo task=detect mode=train epochs=50 imgsz=640 batch=8 plots=True \
model=yolov8n.pt \
data={dataset.location}/data.yaml \
dropout=0.3
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.23M/6.23M [00:00<00:00, 207MB/s]
# New https://pypi.org/project/ultralytics/8.2.35 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/content/coconut-1/data.yaml, epochs=50, patience=50, batch=8, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.3, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 109MB/s]
# 2024-06-18 06:40:48.108646: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-18 06:40:48.108726: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-18 06:40:48.245809: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# Model summary: 225 layers, 3011043 parameters, 3011027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# WARNING ⚠️ NMS time limit 0.550s exceeded
# AMP: checks passed ✅
# train: Scanning /content/coconut-1/train/labels... 144 images, 0 backgrounds, 0 corrupt: 100% 144/144 [00:00<00:00, 1527.77it/s]
# train: New cache created: /content/coconut-1/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /content/coconut-1/valid/labels... 41 images, 0 backgrounds, 0 corrupt: 100% 41/41 [00:00<00:00, 733.48it/s]
# val: New cache created: /content/coconut-1/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      1.24G      1.075       2.41      1.187        160        640: 100% 18/18 [00:07<00:00,  2.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:02<00:00,  1.33it/s]
#                    all         41        490      0.935      0.773      0.885      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      1.21G      1.037     0.9782       1.13        135        640: 100% 18/18 [00:06<00:00,  2.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.68it/s]
#                    all         41        490      0.942      0.863      0.946      0.643
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      1.23G      0.989     0.8456      1.086        123        640: 100% 18/18 [00:03<00:00,  5.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  6.28it/s]
#                    all         41        490       0.97      0.912      0.959      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      1.23G      1.043     0.8343      1.077        143        640: 100% 18/18 [00:03<00:00,  5.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  6.45it/s]
#                    all         41        490      0.977      0.853      0.932      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      1.25G      1.029      0.805       1.08        157        640: 100% 18/18 [00:04<00:00,  4.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.74it/s]
#                    all         41        490      0.982      0.886      0.958      0.666
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      1.22G      1.041     0.8048       1.09        120        640: 100% 18/18 [00:05<00:00,  3.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.77it/s]
#                    all         41        490      0.983      0.972      0.988      0.699
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      1.22G      1.001      0.751       1.09        140        640: 100% 18/18 [00:03<00:00,  5.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.85it/s]
#                    all         41        490      0.983      0.973      0.993      0.735
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      1.22G      1.028     0.7456       1.09        119        640: 100% 18/18 [00:03<00:00,  5.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.66it/s]
#                    all         41        490      0.972      0.955      0.989      0.695
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      1.24G     0.9925     0.7253       1.07        152        640: 100% 18/18 [00:05<00:00,  3.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.03it/s]
#                    all         41        490      0.971      0.967      0.991       0.73
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      1.25G     0.9864     0.7399      1.076        117        640: 100% 18/18 [00:03<00:00,  5.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  6.18it/s]
#                    all         41        490      0.978      0.981      0.994       0.75
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      1.23G     0.9431     0.6966       1.09        126        640: 100% 18/18 [00:03<00:00,  5.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  5.66it/s]
#                    all         41        490      0.974      0.978      0.993      0.754
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      1.22G     0.8972     0.6654       1.04        134        640: 100% 18/18 [00:04<00:00,  4.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.36it/s]
#                    all         41        490      0.979      0.973      0.993      0.749
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      1.21G     0.9222     0.6483      1.051        153        640: 100% 18/18 [00:04<00:00,  3.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  6.11it/s]
#                    all         41        490      0.981      0.965      0.992      0.752
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      1.23G     0.9268      0.653      1.073        112        640: 100% 18/18 [00:03<00:00,  5.83it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.56it/s]
#                    all         41        490      0.989      0.959      0.987      0.742
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      1.22G     0.9035      0.635      1.055        138        640: 100% 18/18 [00:03<00:00,  5.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.14it/s]
#                    all         41        490      0.986      0.979      0.992      0.758
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      1.23G     0.9058      0.628       1.07         89        640: 100% 18/18 [00:05<00:00,  3.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.27it/s]
#                    all         41        490      0.989      0.982      0.994      0.756
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      1.23G     0.9189     0.6228       1.07        106        640: 100% 18/18 [00:03<00:00,  5.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  6.39it/s]
#                    all         41        490      0.977      0.988      0.994      0.764
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      1.22G     0.9393     0.6166      1.086        159        640: 100% 18/18 [00:03<00:00,  5.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  5.25it/s]
#                    all         41        490      0.984      0.992      0.993      0.768
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      1.21G     0.8806     0.5798       1.06        135        640: 100% 18/18 [00:03<00:00,  4.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.98it/s]
#                    all         41        490      0.991      0.986      0.995      0.772
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      1.21G     0.8766     0.5656      1.055        116        640: 100% 18/18 [00:05<00:00,  3.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.55it/s]
#                    all         41        490      0.988      0.988      0.994      0.769
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      1.23G     0.8623       0.56      1.046        162        640: 100% 18/18 [00:03<00:00,  5.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  6.57it/s]
#                    all         41        490      0.989      0.984      0.994      0.767
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      1.21G     0.8892     0.5643      1.052        117        640: 100% 18/18 [00:03<00:00,  5.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  5.17it/s]
#                    all         41        490      0.984      0.982      0.994      0.752
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      1.21G     0.8875     0.5665      1.066        139        640: 100% 18/18 [00:04<00:00,  3.83it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.36it/s]
#                    all         41        490      0.984      0.984      0.994      0.768
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      1.21G     0.8578     0.5492      1.026        167        640: 100% 18/18 [00:03<00:00,  4.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  5.38it/s]
#                    all         41        490       0.98      0.984      0.994      0.763
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      1.23G     0.8708     0.5492      1.054        134        640: 100% 18/18 [00:03<00:00,  5.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  6.31it/s]
#                    all         41        490      0.982      0.983      0.994      0.772
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      1.24G     0.8724     0.5493      1.052        160        640: 100% 18/18 [00:03<00:00,  5.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.60it/s]
#                    all         41        490      0.988      0.973      0.994      0.767
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      1.25G     0.8289     0.5216      1.028        100        640: 100% 18/18 [00:05<00:00,  3.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.27it/s]
#                    all         41        490      0.988      0.981      0.994       0.77
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      1.22G     0.8801     0.5221      1.036        161        640: 100% 18/18 [00:03<00:00,  5.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  6.72it/s]
#                    all         41        490      0.983      0.986      0.994      0.774
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      1.24G     0.8373     0.5122      1.036        149        640: 100% 18/18 [00:03<00:00,  5.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  6.25it/s]
#                    all         41        490      0.978      0.984      0.993      0.776
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      1.22G     0.8569     0.5294      1.037        137        640: 100% 18/18 [00:04<00:00,  4.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.69it/s]
#                    all         41        490      0.986      0.985      0.994      0.768
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      1.21G     0.8266     0.5084      1.042        104        640: 100% 18/18 [00:05<00:00,  3.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  5.97it/s]
#                    all         41        490      0.992       0.98      0.994      0.784
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      1.21G     0.8167     0.5065      1.038        106        640: 100% 18/18 [00:03<00:00,  5.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  6.22it/s]
#                    all         41        490      0.992      0.981      0.994      0.777
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      1.25G     0.8109      0.492      1.031        111        640: 100% 18/18 [00:03<00:00,  5.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  5.40it/s]
#                    all         41        490      0.989       0.98      0.994      0.767
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      1.24G     0.8095     0.4934      1.024         91        640: 100% 18/18 [00:05<00:00,  3.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.73it/s]
#                    all         41        490      0.989      0.973      0.993       0.77
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      1.23G      0.838     0.4874       1.04        177        640: 100% 18/18 [00:03<00:00,  5.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  5.18it/s]
#                    all         41        490      0.991      0.973      0.994       0.77
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      1.23G     0.8334     0.4988      1.034        133        640: 100% 18/18 [00:04<00:00,  3.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.41it/s]
#                    all         41        490      0.991      0.973      0.994      0.779
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      1.24G     0.8142     0.4911      1.033        108        640: 100% 18/18 [00:05<00:00,  3.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.27it/s]
#                    all         41        490       0.99      0.976      0.994      0.775
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      1.21G     0.8109     0.4904      1.028        106        640: 100% 18/18 [00:04<00:00,  4.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  5.57it/s]
#                    all         41        490       0.99      0.978      0.994      0.781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      1.23G     0.8208     0.4796      1.038        130        640: 100% 18/18 [00:03<00:00,  5.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  6.18it/s]
#                    all         41        490      0.988      0.982      0.994      0.785
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      1.21G     0.8026     0.4713      1.028        120        640: 100% 18/18 [00:03<00:00,  5.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.77it/s]
#                    all         41        490       0.98      0.992      0.994      0.781
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      1.33G     0.7376     0.4734      1.006         70        640: 100% 18/18 [00:07<00:00,  2.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  5.19it/s]
#                    all         41        490      0.981      0.988      0.994      0.789
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50       1.2G     0.7457     0.4651      1.008         93        640: 100% 18/18 [00:03<00:00,  5.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  6.48it/s]
#                    all         41        490      0.986      0.984      0.994      0.785
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      1.21G     0.7404     0.4577       1.01         94        640: 100% 18/18 [00:02<00:00,  6.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  5.82it/s]
#                    all         41        490      0.986      0.984      0.994      0.785
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      1.21G     0.7166     0.4409      1.006         75        640: 100% 18/18 [00:05<00:00,  3.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.92it/s]
#                    all         41        490      0.989      0.986      0.994      0.783
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50       1.2G     0.7363     0.4472     0.9967         80        640: 100% 18/18 [00:02<00:00,  6.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  5.40it/s]
#                    all         41        490      0.982       0.99      0.994      0.788
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      1.21G     0.7231     0.4463      1.001         72        640: 100% 18/18 [00:02<00:00,  6.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  6.50it/s]
#                    all         41        490      0.988      0.988      0.994      0.789
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50       1.2G      0.717     0.4317     0.9939         84        640: 100% 18/18 [00:03<00:00,  5.83it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.91it/s]
#                    all         41        490      0.984      0.988      0.994      0.789
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50       1.2G     0.7124      0.421      1.003         83        640: 100% 18/18 [00:05<00:00,  3.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.46it/s]
#                    all         41        490      0.986      0.984      0.994      0.793
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      1.21G     0.7111     0.4213     0.9894         94        640: 100% 18/18 [00:02<00:00,  6.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  5.68it/s]
#                    all         41        490      0.988       0.99      0.995      0.794
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      1.21G     0.7146     0.4201     0.9847         72        640: 100% 18/18 [00:02<00:00,  6.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  6.11it/s]
#                    all         41        490      0.988      0.988      0.995      0.795
#
# 50 epochs completed in 0.076 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.3MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.3MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  1.58it/s]
#                    all         41        490      0.988      0.989      0.995      0.794
# Speed: 0.4ms preprocess, 3.9ms inference, 0.0ms loss, 8.6ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml					    R_curve.png		val_batch0_labels.jpg
# confusion_matrix_normalized.png			    results.csv		val_batch0_pred.jpg
# confusion_matrix.png				    results.png		val_batch1_labels.jpg
# events.out.tfevents.1718692851.ef1d22c3d57b.2643.0  train_batch0.jpg	val_batch1_pred.jpg
# F1_curve.png					    train_batch1.jpg	val_batch2_labels.jpg
# labels_correlogram.jpg				    train_batch2.jpg	val_batch2_pred.jpg
# labels.jpg					    train_batch720.jpg	weights
# P_curve.png					    train_batch721.jpg
# PR_curve.png					    train_batch722.jpg

# %%
from IPython.display import Image, clear_output

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content

# %% [markdown]
# ## Inference with Custom Model

# %% [markdown]
# **NOTE:** Let's start by loading our newly trained model.

# %%
# !pip install supervision
import supervision as sv
# Out:
# Collecting supervision
#   Downloading supervision-0.21.0-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.0/124.0 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from supervision) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from supervision) (3.7.1)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from supervision) (1.25.2)
# Requirement already satisfied: opencv-python-headless>=4.5.5.64 in /usr/local/lib/python3.10/dist-packages (from supervision) (4.8.0.74)
# Requirement already satisfied: pillow>=9.4 in /usr/local/lib/python3.10/dist-packages (from supervision) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.10/dist-packages (from supervision) (6.0.1)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from supervision) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from cycler>=0.10->matplotlib>=3.6.0->supervision) (1.16.0)
# Installing collected packages: supervision
# Successfully installed supervision-0.21.0

# %%
from ultralytics import YOLO

model = YOLO(f'{HOME}/runs/detect/train/weights/best.pt')

dataset = sv.DetectionDataset.from_yolo(
    images_directory_path=f"{dataset.location}/valid/images",
    annotations_directory_path=f"{dataset.location}/valid/labels",
    data_yaml_path=f"{dataset.location}/data.yaml"
)

bounding_box_annotator = sv.BoundingBoxAnnotator()
label_annotator = sv.LabelAnnotator()

# %% [markdown]
# **NOTE:** Let's randomly select an image from our validation set and visualize the results.

# %%
import random

random_image = random.choice(list(dataset.images.keys()))
random_image = dataset.images[random_image]

results = model(source=random_image, conf=0.25)[0]
detections = sv.Detections.from_ultralytics(results)

annotated_image = bounding_box_annotator.annotate(
    scene=random_image, detections=detections)
annotated_image = label_annotator.annotate(
    scene=annotated_image, detections=detections)

sv.plot_image(annotated_image)
# Out:
# 0: 640x640 12 coconuts, 13.7ms
# Speed: 3.9ms preprocess, 13.7ms inference, 544.9ms postprocess per image at shape (1, 3, 640, 640)

# %%
pred = model.predict(random_image, save=True)
pred
# Out:
# 0: 640x640 12 coconutss, 38.2ms
# Speed: 2.5ms preprocess, 38.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'coconuts'}
#  orig_img: array([[[128, 126, 126],
#          [127, 125, 125],
#          [128, 126, 126],
#          ...,
#          [ 95, 107, 113],
#          [ 88, 100, 106],
#          [ 96, 108, 114]],
#
#         [[131, 129, 129],
#          [130, 128, 128],
#          [130, 128, 128],
#          ...,
#          [ 95, 107, 113],
#          [ 87,  99, 105],
#          [ 93, 105, 111]],
#
#         [[134, 132, 132],
#          [133, 131, 131],
#          [130, 130, 130],
#          ...,
#          [ 97, 109, 115],
#          [ 90, 102, 108],
#          [ 93, 105, 111]],
#
#         ...,
#
#         [[115, 145, 156],
#          [116, 146, 157],
#          [117, 147, 158],
#          ...,
#          [ 58,  57,  47],
#          [ 74,  70,  59],
#          [112, 108,  97]],
#
#         [[114, 146, 157],
#          [115, 147, 158],
#          [118, 147, 161],
#          ...,
#          [ 54,  53,  43],
#          [ 69,  65,  54],
#          [106, 102,  91]],
#
#         [[112, 147, 157],
#          [113, 148, 158],
#          [118, 147, 161],
#          ...,
#          [ 51,  50,  40],
#          [ 66,  62,  51],
#          [103,  99,  88]]], dtype=uint8)
#  orig_shape: (640, 640)
#  path: 'image0.jpg'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.4678707122802734, 'inference': 38.233280181884766, 'postprocess': 2.4275779724121094}]

# %% [markdown]
# #Tracking

# %%
# %pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.10/dist-packages (8.0.196)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: numpy>=1.22.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.25.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.3.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.18.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2023.7.22)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics) (12.5.40)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from cycler>=0.10->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)

# %%
# %pip install ultralytics --upgrade
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.10/dist-packages (8.0.196)
# Collecting ultralytics
#   Downloading ultralytics-8.2.34-py3-none-any.whl (780 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.7/780.7 kB 15.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.25.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.3.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.18.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2023.7.22)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics) (12.5.40)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from cycler>=0.10->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: ultralytics-thop, ultralytics
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.196
#     Uninstalling ultralytics-8.0.196:
#       Successfully uninstalled ultralytics-8.0.196
# Successfully installed ultralytics-8.2.34 ultralytics-thop-2.0.0

# %%
# import cv2
# from ultralytics import YOLO, solutions

# %%
import cv2
from ultralytics import YOLO

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")
model.names
# Out:
# {0: 'coconut'}

# %%
# Ultralytics YOLO 🚀, AGPL-3.0 license

from collections import defaultdict

import cv2
import numpy as np

from ultralytics.utils.checks import check_imshow, check_requirements
from ultralytics.utils.plotting import Annotator, colors

check_requirements("shapely>=2.0.0")

from shapely.geometry import LineString, Point, Polygon


class ObjectCounter:
    """A class to manage the counting of objects in a real-time video stream based on their tracks."""

    def __init__(
        self,
        classes_names,
        reg_pts=None,
        count_reg_color=(255, 0, 255),
        count_txt_color=(0, 0, 0),
        count_bg_color=(255, 255, 255),
        line_thickness=2,
        track_thickness=2,
        view_img=False,
        view_counts=True,
        draw_tracks=False,
        track_color=None,
        region_thickness=5,
        line_dist_thresh=15,
        cls_txtdisplay_gap=50,
    ):
        """
        Initializes the ObjectCounter with various tracking and counting parameters.

        Args:
            classes_names (dict): Dictionary of class names.
            reg_pts (list): List of points defining the counting region.
            count_reg_color (tuple): RGB color of the counting region.
            count_txt_color (tuple): RGB color of the count text.
            count_bg_color (tuple): RGB color of the count text background.
            line_thickness (int): Line thickness for bounding boxes.
            track_thickness (int): Thickness of the track lines.
            view_img (bool): Flag to control whether to display the video stream.
            view_counts (bool): Flag to control whether to display the counts on the video stream.
            draw_tracks (bool): Flag to control whether to draw the object tracks.
            track_color (tuple): RGB color of the tracks.
            region_thickness (int): Thickness of the object counting region.
            line_dist_thresh (int): Euclidean distance threshold for line counter.
            cls_txtdisplay_gap (int): Display gap between each class count.
        """

        # Mouse events
        self.is_drawing = False
        self.selected_point = None

        # Region & Line Information
        self.reg_pts = [(20, 400), (1260, 400)] if reg_pts is None else reg_pts
        self.line_dist_thresh = line_dist_thresh
        self.counting_region = None
        self.region_color = count_reg_color
        self.region_thickness = region_thickness

        # Image and annotation Information
        self.im0 = None
        self.tf = line_thickness
        self.view_img = view_img
        self.view_counts = view_counts

        self.names = classes_names  # Classes names
        self.annotator = None  # Annotator
        self.window_name = "Ultralytics YOLOv8 Object Counter"

        # Object counting Information
        self.count_ids = []
        self.class_wise_count = defaultdict(int)
        self.count_txt_thickness = 0
        self.count_txt_color = count_txt_color
        self.count_bg_color = count_bg_color
        self.cls_txtdisplay_gap = cls_txtdisplay_gap
        self.fontsize = 0.6

        # Tracks info
        self.track_history = defaultdict(list)
        self.track_thickness = track_thickness
        self.draw_tracks = draw_tracks
        self.track_color = track_color

        # Check if environment supports imshow
        self.env_check = check_imshow(warn=True)

        # Initialize counting region
        if len(self.reg_pts) == 2:
            print("Line Counter Initiated.")
            self.counting_region = LineString(self.reg_pts)
        elif len(self.reg_pts) >= 3:
            print("Polygon Counter Initiated.")
            self.counting_region = Polygon(self.reg_pts)
        else:
            print("Invalid Region points provided, region_points must be 2 for lines or >= 3 for polygons.")
            print("Using Line Counter Now")
            self.counting_region = LineString(self.reg_pts)

    def mouse_event_for_region(self, event, x, y, flags, params):
        """
        Handles mouse events for defining and moving the counting region in a real-time video stream.

        Args:
            event (int): The type of mouse event (e.g., cv2.EVENT_MOUSEMOVE, cv2.EVENT_LBUTTONDOWN, etc.).
            x (int): The x-coordinate of the mouse pointer.
            y (int): The y-coordinate of the mouse pointer.
            flags (int): Any associated event flags (e.g., cv2.EVENT_FLAG_CTRLKEY,  cv2.EVENT_FLAG_SHIFTKEY, etc.).
            params (dict): Additional parameters for the function.
        """
        if event == cv2.EVENT_LBUTTONDOWN:
            for i, point in enumerate(self.reg_pts):
                if (
                    isinstance(point, (tuple, list))
                    and len(point) >= 2
                    and (abs(x - point[0]) < 10 and abs(y - point[1]) < 10)
                ):
                    self.selected_point = i
                    self.is_drawing = True
                    break

        elif event == cv2.EVENT_MOUSEMOVE:
            if self.is_drawing and self.selected_point is not None:
                self.reg_pts[self.selected_point] = (x, y)
                self.counting_region = Polygon(self.reg_pts)

        elif event == cv2.EVENT_LBUTTONUP:
            self.is_drawing = False
            self.selected_point = None

    def extract_and_process_tracks(self, tracks):
        """Extracts and processes tracks for object counting in a video stream."""

        # Annotator Init and region drawing
        self.annotator = Annotator(self.im0, self.tf, self.names)

        # Draw region or line
        self.annotator.draw_region(reg_pts=self.reg_pts, color=self.region_color, thickness=self.region_thickness)

        if tracks[0].boxes.id is not None:
            boxes = tracks[0].boxes.xyxy.cpu()
            clss = tracks[0].boxes.cls.cpu().tolist()
            track_ids = tracks[0].boxes.id.int().cpu().tolist()

            # Extract tracks
            for box, track_id, cls in zip(boxes, track_ids, clss):
                # Draw bounding box
                self.annotator.box_label(box, label=f"{self.names[cls]}#{track_id}", color=colors(int(track_id), True))

                # Draw Tracks
                track_line = self.track_history[track_id]
                track_line.append((float((box[0] + box[2]) / 2), float((box[1] + box[3]) / 2)))
                if len(track_line) > 30:
                    track_line.pop(0)

                # Draw track trails
                if self.draw_tracks:
                    self.annotator.draw_centroid_and_tracks(
                        track_line,
                        color=self.track_color or colors(int(track_id), True),
                        track_thickness=self.track_thickness,
                    )

                prev_position = self.track_history[track_id][-2] if len(self.track_history[track_id]) > 1 else None

                # Count objects in any polygon
                if len(self.reg_pts) >= 3:
                    is_inside = self.counting_region.contains(Point(track_line[-1]))

                    if prev_position is not None and is_inside and track_id not in self.count_ids:
                        self.count_ids.append(track_id)
                        self.class_wise_count[self.names[cls]] += 1

                # Count objects using line
                elif len(self.reg_pts) == 2:
                    if prev_position is not None and track_id not in self.count_ids:
                        distance = Point(track_line[-1]).distance(self.counting_region)
                        if distance < self.line_dist_thresh and track_id not in self.count_ids:
                            self.count_ids.append(track_id)
                            self.class_wise_count[self.names[cls]] += 1

        labels_dict = {}

        for key, value in self.class_wise_count.items():
            if value != 0:
                labels_dict[str.capitalize(key)] = f"Count {value}"

        if labels_dict:
            self.annotator.display_analytics(self.im0, labels_dict, self.count_txt_color, self.count_bg_color, 10)

    def display_frames(self):
        """Displays the current frame with annotations and regions in a window."""
        if self.env_check:
            cv2.namedWindow(self.window_name)
            if len(self.reg_pts) == 4:  # only add mouse event If user drawn region
                cv2.setMouseCallback(self.window_name, self.mouse_event_for_region, {"region_points": self.reg_pts})
            cv2.imshow(self.window_name, self.im0)
            # Break Window
            if cv2.waitKey(1) & 0xFF == ord("q"):
                return

    def start_counting(self, im0, tracks):
        """
        Main function to start the object counting process.

        Args:
            im0 (ndarray): Current frame from the video stream.
            tracks (list): List of tracks obtained from the object tracking process.
        """
        self.im0 = im0  # store image
        self.extract_and_process_tracks(tracks)  # draw region even if no objects

        if self.view_img:
            self.display_frames()
        return self.im0


if __name__ == "__main__":
    # classes_names = {0: "person", 1: "car"}  # example class names
    classes_names = {0: 'coconut'}
    object_counter = ObjectCounter(classes_names)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
# Line Counter Initiated.

# %%
# Ultralytics YOLO 🚀, AGPL-3.0 license

import contextlib
import math
import warnings
from pathlib import Path

import cv2
import matplotlib.pyplot as plt
import numpy as np
import torch
from PIL import Image, ImageDraw, ImageFont
from PIL import __version__ as pil_version

from ultralytics.utils import LOGGER, TryExcept, ops, plt_settings, threaded
from ultralytics.utils.checks import check_font, check_version, is_ascii
from ultralytics.utils.files import increment_path

class Annotator:
    """
    Ultralytics Annotator for train/val mosaics and JPGs and predictions annotations.

    Attributes:
        im (Image.Image or numpy array): The image to annotate.
        pil (bool): Whether to use PIL or cv2 for drawing annotations.
        font (ImageFont.truetype or ImageFont.load_default): Font used for text annotations.
        lw (float): Line width for drawing.
        skeleton (List[List[int]]): Skeleton structure for keypoints.
        limb_color (List[int]): Color palette for limbs.
        kpt_color (List[int]): Color palette for keypoints.
    """

    def __init__(self, im, line_width=None, font_size=None, font="Arial.ttf", pil=False, example="abc"):
        """Initialize the Annotator class with image and line width along with color palette for keypoints and limbs."""
        non_ascii = not is_ascii(example)  # non-latin labels, i.e. asian, arabic, cyrillic
        input_is_pil = isinstance(im, Image.Image)
        self.pil = pil or non_ascii or input_is_pil
        self.lw = line_width or max(round(sum(im.size if input_is_pil else im.shape) / 2 * 0.003), 2)
        if self.pil:  # use PIL
            self.im = im if input_is_pil else Image.fromarray(im)
            self.draw = ImageDraw.Draw(self.im)
            try:
                font = check_font("Arial.Unicode.ttf" if non_ascii else font)
                size = font_size or max(round(sum(self.im.size) / 2 * 0.035), 12)
                self.font = ImageFont.truetype(str(font), size)
            except Exception:
                self.font = ImageFont.load_default()
            # Deprecation fix for w, h = getsize(string) -> _, _, w, h = getbox(string)
            if check_version(pil_version, "9.2.0"):
                self.font.getsize = lambda x: self.font.getbbox(x)[2:4]  # text width, height
        else:  # use cv2
            assert im.data.contiguous, "Image not contiguous. Apply np.ascontiguousarray(im) to Annotator input images."
            self.im = im if im.flags.writeable else im.copy()
            self.tf = max(self.lw - 1, 1)  # font thickness
            self.sf = self.lw / 3  # font scale
        # Pose
        self.skeleton = [
            [16, 14],
            [14, 12],
            [17, 15],
            [15, 13],
            [12, 13],
            [6, 12],
            [7, 13],
            [6, 7],
            [6, 8],
            [7, 9],
            [8, 10],
            [9, 11],
            [2, 3],
            [1, 2],
            [1, 3],
            [2, 4],
            [3, 5],
            [4, 6],
            [5, 7],
        ]

        self.limb_color = colors.pose_palette[[9, 9, 9, 9, 7, 7, 7, 0, 0, 0, 0, 0, 16, 16, 16, 16, 16, 16, 16]]
        self.kpt_color = colors.pose_palette[[16, 16, 16, 16, 16, 0, 0, 0, 0, 0, 0, 9, 9, 9, 9, 9, 9]]

    def draw_region(self, reg_pts=None, color=(0, 255, 0), thickness=5):
        """
        Draw region line.

        Args:
            reg_pts (list): Region Points (for line 2 points, for region 4 points)
            color (tuple): Region Color value
            thickness (int): Region area thickness value
        """
        cv2.polylines(self.im, [np.array(reg_pts, dtype=np.int32)], isClosed=True, color=color, thickness=thickness)

    def box_label(self, box, label="", color=(128, 128, 128), txt_color=(255, 255, 255), rotated=False):
        """Add one xyxy box to image with label."""
        if isinstance(box, torch.Tensor):
            box = box.tolist()
        if self.pil or not is_ascii(label):
            if rotated:
                p1 = box[0]
                # NOTE: PIL-version polygon needs tuple type.
                self.draw.polygon([tuple(b) for b in box], width=self.lw, outline=color)
            else:
                p1 = (box[0], box[1])
                self.draw.rectangle(box, width=self.lw, outline=color)  # box
            if label:
                w, h = self.font.getsize(label)  # text width, height
                outside = p1[1] - h >= 0  # label fits outside box
                self.draw.rectangle(
                    (p1[0], p1[1] - h if outside else p1[1], p1[0] + w + 1, p1[1] + 1 if outside else p1[1] + h + 1),
                    fill=color,
                )
                # self.draw.text((box[0], box[1]), label, fill=txt_color, font=self.font, anchor='ls')  # for PIL>8.0
                self.draw.text((p1[0], p1[1] - h if outside else p1[1]), label, fill=txt_color, font=self.font)
        else:  # cv2
            if rotated:
                p1 = [int(b) for b in box[0]]
                # NOTE: cv2-version polylines needs np.asarray type.
                cv2.polylines(self.im, [np.asarray(box, dtype=int)], True, color, self.lw)
            else:
                p1, p2 = (int(box[0]), int(box[1])), (int(box[2]), int(box[3]))
                cv2.rectangle(self.im, p1, p2, color, thickness=self.lw, lineType=cv2.LINE_AA)
            if label:
                w, h = cv2.getTextSize(label, 0, fontScale=self.sf, thickness=self.tf)[0]  # text width, height
                outside = p1[1] - h >= 3
                p2 = p1[0] + w, p1[1] - h - 3 if outside else p1[1] + h + 3
                cv2.rectangle(self.im, p1, p2, color, -1, cv2.LINE_AA)  # filled
                cv2.putText(
                    self.im,
                    label,
                    (p1[0], p1[1] - 2 if outside else p1[1] + h + 2),
                    0,
                    self.sf,
                    txt_color,
                    thickness=self.tf,
                    lineType=cv2.LINE_AA,
                )

    def display_analytics(self, im0, text, txt_color, bg_color, margin):
        """
        Display the overall statistics for parking lots
        Args:
            im0 (ndarray): inference image
            text (dict): labels dictionary
            txt_color (bgr color): display color for text foreground
            bg_color (bgr color): display color for text background
            margin (int): gap between text and rectangle for better display
        """

        horizontal_gap = int(im0.shape[1] * 0.02)
        vertical_gap = int(im0.shape[0] * 0.01)
        text_y_offset = 0
        for label, value in text.items():
            txt = f"{label}: {value}"
            text_size = cv2.getTextSize(txt, 0, self.sf, self.tf)[0]
            if text_size[0] < 5 or text_size[1] < 5:
                text_size = (5, 5)
            text_x = im0.shape[1] - text_size[0] - margin * 2 - horizontal_gap
            text_y = text_y_offset + text_size[1] + margin * 2 + vertical_gap
            rect_x1 = text_x - margin * 2
            rect_y1 = text_y - text_size[1] - margin * 2
            rect_x2 = text_x + text_size[0] + margin * 2
            rect_y2 = text_y + margin * 2
            cv2.rectangle(im0, (rect_x1, rect_y1), (rect_x2, rect_y2), bg_color, -1)
            cv2.putText(im0, txt, (text_x, text_y), 0, self.sf, txt_color, self.tf, lineType=cv2.LINE_AA)
            text_y_offset = rect_y2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#ใช้อันนี้
import cv2

from ultralytics import YOLO

model = YOLO("/content/runs/detect/train/weights/best.pt")
cap = cv2.VideoCapture("/content/drive/MyDrive/coconut/FAST conveyor coconut engraving laser machine1000pcs_h.mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

line_points = [(20, 400), (1260, 400)]
classes_to_count = [0]

# Video writer
video_writer = cv2.VideoWriter("output.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# Init Object Counter
# object_counter = ObjectCounter(
#     view_img=True,
#     reg_pts=line_points,
#     classes_names=model.names,
#     view_counts=True,
#     draw_tracks=True,
#     line_thickness=2,
# )
object_counter = ObjectCounter(classes_names)

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    tracks = model.track(im0, persist=True, show=False, classes=classes_to_count)

    im0 = object_counter.start_counting(im0, tracks)
    video_writer.write(im0)

cap.release()
video_writer.release()
cv2.destroyAllWindows()
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
# Line Counter Initiated.
# 0: 640x352 4 coconuts, 111.1ms
# Speed: 1.8ms preprocess, 111.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 9.6ms
# Speed: 2.1ms preprocess, 9.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 5 coconuts, 9.3ms
# Speed: 2.6ms preprocess, 9.3ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 7.9ms
# Speed: 2.4ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.3ms
# Speed: 2.3ms preprocess, 8.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 9.1ms
# Speed: 2.2ms preprocess, 9.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.7ms
# Speed: 3.7ms preprocess, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 15.3ms
# Speed: 3.2ms preprocess, 15.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 8.2ms
# Speed: 2.2ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 9.8ms
# Speed: 2.0ms preprocess, 9.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 7.4ms
# Speed: 2.3ms preprocess, 7.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 10.3ms
# Speed: 2.1ms preprocess, 10.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 11.8ms
# Speed: 2.2ms preprocess, 11.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 12.2ms
# Speed: 1.9ms preprocess, 12.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 13.6ms
# Speed: 1.9ms preprocess, 13.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 10.4ms
# Speed: 2.3ms preprocess, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 10.7ms
# Speed: 1.8ms preprocess, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 26.8ms
# Speed: 3.9ms preprocess, 26.8ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 14.6ms
# Speed: 2.7ms preprocess, 14.6ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 11.5ms
# Speed: 3.2ms preprocess, 11.5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 15.5ms
# Speed: 4.6ms preprocess, 15.5ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 13.3ms
# Speed: 2.5ms preprocess, 13.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 7.4ms
# Speed: 2.0ms preprocess, 7.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 9.6ms
# Speed: 4.2ms preprocess, 9.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 12.6ms
# Speed: 1.9ms preprocess, 12.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 7.9ms
# Speed: 2.3ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 7.7ms
# Speed: 1.9ms preprocess, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.1ms
# Speed: 4.5ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.5ms
# Speed: 1.7ms preprocess, 7.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 11.0ms
# Speed: 1.8ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 14.1ms
# Speed: 2.1ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 10.5ms
# Speed: 2.1ms preprocess, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 13.1ms
# Speed: 2.4ms preprocess, 13.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 10.3ms
# Speed: 2.5ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 10.5ms
# Speed: 2.1ms preprocess, 10.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 11.1ms
# Speed: 2.1ms preprocess, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 12.0ms
# Speed: 3.1ms preprocess, 12.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 9.4ms
# Speed: 2.8ms preprocess, 9.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 6.8ms
# Speed: 2.2ms preprocess, 6.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.0ms
# Speed: 2.4ms preprocess, 7.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.6ms
# Speed: 1.8ms preprocess, 7.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.1ms
# Speed: 1.8ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.6ms
# Speed: 2.4ms preprocess, 7.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.9ms
# Speed: 2.5ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.1ms
# Speed: 2.4ms preprocess, 7.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 12.0ms
# Speed: 3.7ms preprocess, 12.0ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 15.5ms
# Speed: 3.9ms preprocess, 15.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 17.7ms
# Speed: 3.3ms preprocess, 17.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 14.4ms
# Speed: 3.3ms preprocess, 14.4ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 12.9ms
# Speed: 2.0ms preprocess, 12.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 11.3ms
# Speed: 1.9ms preprocess, 11.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 13.2ms
# Speed: 1.9ms preprocess, 13.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 15.0ms
# Speed: 1.9ms preprocess, 15.0ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 16.2ms
# Speed: 2.5ms preprocess, 16.2ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 17.1ms
# Speed: 1.8ms preprocess, 17.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 14.1ms
# Speed: 3.6ms preprocess, 14.1ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 16.5ms
# Speed: 4.5ms preprocess, 16.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 12.4ms
# Speed: 4.5ms preprocess, 12.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 12.4ms
# Speed: 3.4ms preprocess, 12.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 16.0ms
# Speed: 2.7ms preprocess, 16.0ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 13.4ms
# Speed: 4.1ms preprocess, 13.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 14.0ms
# Speed: 3.7ms preprocess, 14.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 15.3ms
# Speed: 2.2ms preprocess, 15.3ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 14.2ms
# Speed: 2.5ms preprocess, 14.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 13.2ms
# Speed: 2.0ms preprocess, 13.2ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 14.4ms
# Speed: 2.1ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 12.5ms
# Speed: 2.1ms preprocess, 12.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 12.8ms
# Speed: 2.1ms preprocess, 12.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 12.0ms
# Speed: 1.9ms preprocess, 12.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 11.9ms
# Speed: 1.9ms preprocess, 11.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 10.3ms
# Speed: 1.8ms preprocess, 10.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 13.8ms
# Speed: 1.8ms preprocess, 13.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 13.3ms
# Speed: 2.0ms preprocess, 13.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 17.7ms
# Speed: 2.0ms preprocess, 17.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 18.8ms
# Speed: 2.1ms preprocess, 18.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 10.6ms
# Speed: 2.1ms preprocess, 10.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 18.0ms
# Speed: 1.9ms preprocess, 18.0ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 14.3ms
# Speed: 1.9ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 13.0ms
# Speed: 1.9ms preprocess, 13.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 14.3ms
# Speed: 1.9ms preprocess, 14.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 12.8ms
# Speed: 2.0ms preprocess, 12.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 12.1ms
# Speed: 1.9ms preprocess, 12.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 10.9ms
# Speed: 1.8ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 12.2ms
# Speed: 3.2ms preprocess, 12.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 10.9ms
# Speed: 5.7ms preprocess, 10.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 12.9ms
# Speed: 2.1ms preprocess, 12.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 17.0ms
# Speed: 2.1ms preprocess, 17.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 5 coconuts, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 5 coconuts, 12.0ms
# Speed: 2.1ms preprocess, 12.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 5 coconuts, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 5 coconuts, 17.2ms
# Speed: 2.1ms preprocess, 17.2ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 16.4ms
# Speed: 2.2ms preprocess, 16.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 5 coconuts, 18.2ms
# Speed: 3.2ms preprocess, 18.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 5 coconuts, 16.6ms
# Speed: 1.9ms preprocess, 16.6ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 12.6ms
# Speed: 3.3ms preprocess, 12.6ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 10.8ms
# Speed: 2.4ms preprocess, 10.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 11.2ms
# Speed: 2.5ms preprocess, 11.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 9.4ms
# Speed: 2.0ms preprocess, 9.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 8.7ms
# Speed: 2.4ms preprocess, 8.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 9.6ms
# Speed: 2.5ms preprocess, 9.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 14.0ms
# Speed: 2.1ms preprocess, 14.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 9.7ms
# Speed: 2.0ms preprocess, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 11.1ms
# Speed: 1.9ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 10.4ms
# Speed: 2.0ms preprocess, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 11.8ms
# Speed: 2.2ms preprocess, 11.8ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 10.7ms
# Speed: 2.4ms preprocess, 10.7ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 10.8ms
# Speed: 2.7ms preprocess, 10.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 11.9ms
# Speed: 1.9ms preprocess, 11.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 14.6ms
# Speed: 5.5ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 19.3ms
# Speed: 3.3ms preprocess, 19.3ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 20.3ms
# Speed: 3.9ms preprocess, 20.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 14.6ms
# Speed: 2.1ms preprocess, 14.6ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 18.2ms
# Speed: 2.1ms preprocess, 18.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 15.7ms
# Speed: 3.9ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 13.4ms
# Speed: 1.9ms preprocess, 13.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 14.8ms
# Speed: 4.6ms preprocess, 14.8ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 19.5ms
# Speed: 2.1ms preprocess, 19.5ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 12.8ms
# Speed: 1.9ms preprocess, 12.8ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 12.9ms
# Speed: 2.9ms preprocess, 12.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 13.5ms
# Speed: 1.9ms preprocess, 13.5ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 13.1ms
# Speed: 2.7ms preprocess, 13.1ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 12.7ms
# Speed: 1.9ms preprocess, 12.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 14.2ms
# Speed: 2.1ms preprocess, 14.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 19.6ms
# Speed: 1.8ms preprocess, 19.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 10.5ms
# Speed: 2.3ms preprocess, 10.5ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 14.1ms
# Speed: 3.9ms preprocess, 14.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 15.8ms
# Speed: 2.1ms preprocess, 15.8ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 16.2ms
# Speed: 2.1ms preprocess, 16.2ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 13.0ms
# Speed: 1.9ms preprocess, 13.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 13.6ms
# Speed: 2.0ms preprocess, 13.6ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 11.8ms
# Speed: 1.9ms preprocess, 11.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 12.5ms
# Speed: 1.9ms preprocess, 12.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 14.6ms
# Speed: 1.9ms preprocess, 14.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 14.0ms
# Speed: 1.9ms preprocess, 14.0ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 12.7ms
# Speed: 4.9ms preprocess, 12.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 11.8ms
# Speed: 1.8ms preprocess, 11.8ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 12.6ms
# Speed: 2.2ms preprocess, 12.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 20.3ms
# Speed: 2.1ms preprocess, 20.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 18.9ms
# Speed: 1.9ms preprocess, 18.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 15.3ms
# Speed: 2.2ms preprocess, 15.3ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 13.7ms
# Speed: 4.6ms preprocess, 13.7ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 13.9ms
# Speed: 2.0ms preprocess, 13.9ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 12.3ms
# Speed: 4.3ms preprocess, 12.3ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 16.1ms
# Speed: 3.6ms preprocess, 16.1ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 20.2ms
# Speed: 2.1ms preprocess, 20.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 11.7ms
# Speed: 2.2ms preprocess, 11.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 15.6ms
# Speed: 4.4ms preprocess, 15.6ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 17.7ms
# Speed: 2.0ms preprocess, 17.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 10.4ms
# Speed: 2.0ms preprocess, 10.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 12.2ms
# Speed: 2.3ms preprocess, 12.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 18.1ms
# Speed: 5.1ms preprocess, 18.1ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 10.9ms
# Speed: 4.7ms preprocess, 10.9ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 13.3ms
# Speed: 3.5ms preprocess, 13.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.4ms
# Speed: 1.9ms preprocess, 7.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 8.2ms
# Speed: 1.8ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 8.1ms
# Speed: 1.9ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.8ms
# Speed: 1.8ms preprocess, 7.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.7ms
# Speed: 2.0ms preprocess, 7.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.6ms
# Speed: 1.9ms preprocess, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 11.4ms
# Speed: 1.9ms preprocess, 11.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 9.0ms
# Speed: 1.9ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.4ms
# Speed: 1.8ms preprocess, 7.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 12.0ms
# Speed: 2.1ms preprocess, 12.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 10.4ms
# Speed: 3.4ms preprocess, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 12.4ms
# Speed: 2.7ms preprocess, 12.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 12.5ms
# Speed: 1.9ms preprocess, 12.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 14.2ms
# Speed: 4.4ms preprocess, 14.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 19.5ms
# Speed: 2.2ms preprocess, 19.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 12.8ms
# Speed: 2.0ms preprocess, 12.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 9.6ms
# Speed: 3.8ms preprocess, 9.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 13.3ms
# Speed: 2.0ms preprocess, 13.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 11.8ms
# Speed: 2.3ms preprocess, 11.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.6ms
# Speed: 1.9ms preprocess, 7.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.5ms
# Speed: 2.3ms preprocess, 7.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.3ms
# Speed: 2.6ms preprocess, 7.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 9.0ms
# Speed: 1.8ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 9.9ms
# Speed: 1.9ms preprocess, 9.9ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.7ms
# Speed: 2.2ms preprocess, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.4ms
# Speed: 3.0ms preprocess, 7.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.3ms
# Speed: 1.8ms preprocess, 7.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 10.4ms
# Speed: 1.9ms preprocess, 10.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.5ms
# Speed: 2.2ms preprocess, 7.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.4ms
# Speed: 1.7ms preprocess, 7.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 12.3ms
# Speed: 2.3ms preprocess, 12.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 14.1ms
# Speed: 2.1ms preprocess, 14.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 16.2ms
# Speed: 2.2ms preprocess, 16.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 13.3ms
# Speed: 2.3ms preprocess, 13.3ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 17.8ms
# Speed: 1.9ms preprocess, 17.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 11.7ms
# Speed: 2.2ms preprocess, 11.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 5 coconuts, 15.4ms
# Speed: 1.9ms preprocess, 15.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 5 coconuts, 13.3ms
# Speed: 1.9ms preprocess, 13.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 5 coconuts, 12.6ms
# Speed: 2.1ms preprocess, 12.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 5 coconuts, 12.7ms
# Speed: 2.2ms preprocess, 12.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 5 coconuts, 9.5ms
# Speed: 2.1ms preprocess, 9.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 8.4ms
# Speed: 1.9ms preprocess, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.9ms
# Speed: 2.2ms preprocess, 7.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 10.0ms
# Speed: 2.3ms preprocess, 10.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.6ms
# Speed: 1.9ms preprocess, 7.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.5ms
# Speed: 2.5ms preprocess, 7.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 10.7ms
# Speed: 2.0ms preprocess, 10.7ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 7.9ms
# Speed: 1.9ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 7.1ms
# Speed: 2.1ms preprocess, 7.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 7.7ms
# Speed: 2.0ms preprocess, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 9.6ms
# Speed: 2.0ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 13.0ms
# Speed: 1.8ms preprocess, 13.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 10.0ms
# Speed: 3.8ms preprocess, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 9.9ms
# Speed: 2.4ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 11.7ms
# Speed: 2.1ms preprocess, 11.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 14.5ms
# Speed: 5.8ms preprocess, 14.5ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 12.5ms
# Speed: 2.6ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 13.4ms
# Speed: 1.9ms preprocess, 13.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 11.1ms
# Speed: 2.1ms preprocess, 11.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 14.1ms
# Speed: 3.5ms preprocess, 14.1ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 10.7ms
# Speed: 2.1ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 12.8ms
# Speed: 2.8ms preprocess, 12.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.7ms
# Speed: 2.7ms preprocess, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.2ms
# Speed: 1.8ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 5 coconuts, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 5 coconuts, 8.4ms
# Speed: 1.9ms preprocess, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 5 coconuts, 8.4ms
# Speed: 2.2ms preprocess, 8.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 5 coconuts, 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 7.6ms
# Speed: 1.9ms preprocess, 7.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 12.7ms
# Speed: 1.9ms preprocess, 12.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 6.9ms
# Speed: 3.2ms preprocess, 6.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 7.5ms
# Speed: 1.8ms preprocess, 7.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 6.5ms
# Speed: 2.2ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 8.6ms
# Speed: 2.4ms preprocess, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 16.9ms
# Speed: 1.9ms preprocess, 16.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 10.0ms
# Speed: 2.3ms preprocess, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 12.9ms
# Speed: 1.9ms preprocess, 12.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 10.6ms
# Speed: 2.3ms preprocess, 10.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 10.0ms
# Speed: 4.6ms preprocess, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 4 coconuts, 13.9ms
# Speed: 2.2ms preprocess, 13.9ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 16.2ms
# Speed: 1.8ms preprocess, 16.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 14.8ms
# Speed: 2.4ms preprocess, 14.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 20.9ms
# Speed: 2.8ms preprocess, 20.9ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 9.3ms
# Speed: 2.2ms preprocess, 9.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 7.6ms
# Speed: 1.9ms preprocess, 7.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 8.0ms
# Speed: 2.2ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.9ms
# Speed: 1.9ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.5ms
# Speed: 1.8ms preprocess, 7.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.9ms
# Speed: 1.8ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 9.7ms
# Speed: 3.2ms preprocess, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 11.0ms
# Speed: 1.9ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 8.6ms
# Speed: 1.9ms preprocess, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.9ms
# Speed: 1.9ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 8.6ms
# Speed: 1.6ms preprocess, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 8.9ms
# Speed: 2.5ms preprocess, 8.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.4ms
# Speed: 2.1ms preprocess, 7.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.1ms
# Speed: 2.3ms preprocess, 7.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 11.2ms
# Speed: 1.8ms preprocess, 11.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 11.3ms
# Speed: 2.1ms preprocess, 11.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 13.5ms
# Speed: 2.1ms preprocess, 13.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 10.3ms
# Speed: 2.2ms preprocess, 10.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 14.5ms
# Speed: 2.2ms preprocess, 14.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 13.5ms
# Speed: 2.3ms preprocess, 13.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 12.1ms
# Speed: 2.9ms preprocess, 12.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 17.4ms
# Speed: 2.8ms preprocess, 17.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 12.1ms
# Speed: 1.8ms preprocess, 12.1ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 8.5ms
# Speed: 2.5ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 13.1ms
# Speed: 1.9ms preprocess, 13.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.7ms
# Speed: 2.0ms preprocess, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 8.0ms
# Speed: 2.2ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.7ms
# Speed: 1.8ms preprocess, 7.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.4ms
# Speed: 2.1ms preprocess, 7.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 10.3ms
# Speed: 1.9ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.9ms
# Speed: 1.9ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 8.6ms
# Speed: 1.9ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.9ms
# Speed: 4.6ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 12.9ms
# Speed: 1.7ms preprocess, 12.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 12.8ms
# Speed: 3.0ms preprocess, 12.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 14.4ms
# Speed: 3.3ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 11.8ms
# Speed: 2.0ms preprocess, 11.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 15.3ms
# ...
#
# 0: 640x352 1 coconut, 17.3ms
# Speed: 2.5ms preprocess, 17.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 10.7ms
# Speed: 2.1ms preprocess, 10.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 14.2ms
# Speed: 3.2ms preprocess, 14.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 13.8ms
# Speed: 2.1ms preprocess, 13.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 11.7ms
# Speed: 1.9ms preprocess, 11.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 14.2ms
# Speed: 2.1ms preprocess, 14.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 13.7ms
# Speed: 1.9ms preprocess, 13.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.7ms
# Speed: 2.0ms preprocess, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 9.9ms
# Speed: 2.0ms preprocess, 9.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 8.3ms
# Speed: 2.3ms preprocess, 8.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 11.1ms
# Speed: 2.4ms preprocess, 11.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 12.7ms
# Speed: 2.1ms preprocess, 12.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.3ms
# Speed: 2.4ms preprocess, 7.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.5ms
# Speed: 2.4ms preprocess, 7.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 13.2ms
# Speed: 2.4ms preprocess, 13.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 8.7ms
# Speed: 2.3ms preprocess, 8.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 9.2ms
# Speed: 2.5ms preprocess, 9.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 10.2ms
# Speed: 1.7ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.1ms
# Speed: 2.1ms preprocess, 7.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 6.9ms
# Speed: 3.2ms preprocess, 6.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 10.4ms
# Speed: 2.8ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 8.4ms
# Speed: 1.8ms preprocess, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 7.5ms
# Speed: 2.1ms preprocess, 7.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 9.9ms
# Speed: 1.9ms preprocess, 9.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 10.3ms
# Speed: 1.9ms preprocess, 10.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 11.0ms
# Speed: 4.6ms preprocess, 11.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 20.9ms
# Speed: 2.2ms preprocess, 20.9ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 17.0ms
# Speed: 4.6ms preprocess, 17.0ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 17.7ms
# Speed: 2.1ms preprocess, 17.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 18.0ms
# Speed: 3.9ms preprocess, 18.0ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 14.3ms
# Speed: 1.9ms preprocess, 14.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 17.9ms
# Speed: 2.0ms preprocess, 17.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 20.3ms
# Speed: 2.2ms preprocess, 20.3ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 16.2ms
# Speed: 2.1ms preprocess, 16.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 17.0ms
# Speed: 2.2ms preprocess, 17.0ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 19.3ms
# Speed: 2.1ms preprocess, 19.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 14.2ms
# Speed: 2.6ms preprocess, 14.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 16.6ms
# Speed: 2.1ms preprocess, 16.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 14.9ms
# Speed: 3.5ms preprocess, 14.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 18.0ms
# Speed: 2.1ms preprocess, 18.0ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 12.9ms
# Speed: 4.4ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 13.8ms
# Speed: 2.1ms preprocess, 13.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 12.5ms
# Speed: 2.1ms preprocess, 12.5ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 10.8ms
# Speed: 6.0ms preprocess, 10.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 12.2ms
# Speed: 2.1ms preprocess, 12.2ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 12.0ms
# Speed: 1.8ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 20.5ms
# Speed: 3.3ms preprocess, 20.5ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 15.9ms
# Speed: 3.3ms preprocess, 15.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 12.9ms
# Speed: 2.1ms preprocess, 12.9ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 9.7ms
# Speed: 2.1ms preprocess, 9.7ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 10.4ms
# Speed: 2.0ms preprocess, 10.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 11.2ms
# Speed: 2.6ms preprocess, 11.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 10.7ms
# Speed: 2.1ms preprocess, 10.7ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 10.3ms
# Speed: 2.1ms preprocess, 10.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 10.9ms
# Speed: 1.9ms preprocess, 10.9ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 10.5ms
# Speed: 2.2ms preprocess, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 12.1ms
# Speed: 2.3ms preprocess, 12.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 11.4ms
# Speed: 2.0ms preprocess, 11.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 12.1ms
# Speed: 2.1ms preprocess, 12.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 10.7ms
# Speed: 2.1ms preprocess, 10.7ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 9.0ms
# Speed: 1.8ms preprocess, 9.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 11.1ms
# Speed: 1.9ms preprocess, 11.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 10.8ms
# Speed: 1.8ms preprocess, 10.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 9.7ms
# Speed: 2.1ms preprocess, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 11.7ms
# Speed: 1.8ms preprocess, 11.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 11.9ms
# Speed: 1.8ms preprocess, 11.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 13.5ms
# Speed: 1.8ms preprocess, 13.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 16.6ms
# Speed: 2.3ms preprocess, 16.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 15.8ms
# Speed: 4.0ms preprocess, 15.8ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 3 coconuts, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 17.1ms
# Speed: 2.5ms preprocess, 17.1ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 15.5ms
# Speed: 2.8ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 17.5ms
# Speed: 2.0ms preprocess, 17.5ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 18.4ms
# Speed: 2.0ms preprocess, 18.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 18.9ms
# Speed: 1.8ms preprocess, 18.9ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 17.6ms
# Speed: 1.9ms preprocess, 17.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 15.5ms
# Speed: 2.5ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 15.8ms
# Speed: 1.9ms preprocess, 15.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 14.5ms
# Speed: 4.0ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 12.7ms
# Speed: 1.7ms preprocess, 12.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 11.0ms
# Speed: 1.9ms preprocess, 11.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 2 coconuts, 14.9ms
# Speed: 1.8ms preprocess, 14.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 30.1ms
# Speed: 1.9ms preprocess, 30.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 32.6ms
# Speed: 2.5ms preprocess, 32.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 24.9ms
# Speed: 4.9ms preprocess, 24.9ms inference, 9.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 13.0ms
# Speed: 5.9ms preprocess, 13.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 10.9ms
# Speed: 4.9ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 18.1ms
# Speed: 1.7ms preprocess, 18.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 15.2ms
# Speed: 1.9ms preprocess, 15.2ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 11.5ms
# Speed: 1.8ms preprocess, 11.5ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 (no detections), 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 12.8ms
# Speed: 4.0ms preprocess, 12.8ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 10.9ms
# Speed: 1.8ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 11.1ms
# Speed: 5.6ms preprocess, 11.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 11.4ms
# Speed: 2.0ms preprocess, 11.4ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 12.0ms
# Speed: 1.9ms preprocess, 12.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 9.7ms
# Speed: 1.7ms preprocess, 9.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 10.8ms
# Speed: 2.9ms preprocess, 10.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 11.4ms
# Speed: 1.6ms preprocess, 11.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 11.2ms
# Speed: 1.7ms preprocess, 11.2ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 9.8ms
# Speed: 3.4ms preprocess, 9.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 13.5ms
# Speed: 2.2ms preprocess, 13.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 coconut, 12.4ms
# Speed: 1.6ms preprocess, 12.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 352)
# Video frame is empty or video processing has been successfully completed.
